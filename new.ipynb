# %% [markdown]
# <a href="https://colab.research.google.com/github/venkat18-ram/colab/blob/main/new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age=21
name='Venkat Ram'
print(f"my name is {name} and i am {age} years old")
# Out:
# my name is Venkat Ram and i am 21 years old
